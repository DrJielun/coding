# %% [markdown]
# ## **Practical Assignment**
# >### Module: Coding Essentials
# >### Module Code: EG33009FP
# >### Duration: 3 hours
# >### Assessment: Perform basic programming (C1 & C2)

# %% [markdown]
# 1. This practical Assignment consists of **TWO** parts.
#
# 	> **Part A: Program Design and Preparation**
#
# 	> **Part B: Program Implementation**

# %% [markdown]
# #### **Task Scenario**
#
# > Precision Manufacturing Solutions is a contract manufacturing company located in Tuas Industrial Park,specializing in precision metal components for the aerospace and automotive industries.
# > The company operates two critical production machines:
# >  - a CNC Milling Machine (for precision cutting) and
# > - a Hydraulic Press (for metal forming).
# >
# > Due to the high-precision requirements of their clients like Singapore Technologies and local automotiveparts suppliers, both machines must maintain strict operational standards. Any unexpected downtime canresult in delayed deliveries and contract penalties of up to $20,000 per day.The company follows a preventive maintenance schedule where each machine requires a comprehensive90-day maintenance check to ensure optimal performance and prevent costly breakdowns. Additionally,daily operational checks are performed to monitor basic functionality and safety parameters.
# >
# >Last month, the Hydraulic Press experienced an unexpected failure that halted production for 16 hours,costing the company $35,000 in lost revenue and rush delivery penalties. Investigation revealed that the90-day maintenance was overdue by 12 days, and daily checks had been inconsistently recorded onpaper forms that were often misplaced or forgotten during shift changes.
# >
# >The production manager has now mandated a digital tracking system to ensure maintenance schedulesare strictly followed. When maintenance is overdue, production must stop immediately and maintenancetags must be placed on the equipment until servicing is completed.
# >Your supervisor has assigned you to develop a Python program that tracks the maintenance status ofboth machines, ensures daily checks are recorded, and provides clear warnings when 90-daymaintenance is approaching or overdue.

# %% [markdown]
# #### **Program Requirements**
#
# 1. Display last date of 90-day maintenance check of 2 machines: CNC Milling and Hydraulic Press
# 2. User inputs daily check completion by entering yes/no for both machines
# 3. User inputs date of daily check (DD/MM/YY format)
# 4. Each machine has a 90-day maintenance cycle - program calculates days remaining until nextmaintenance
# 5. Flag machines that are overdue for maintenance and prompt user to place maintenance tag

# %% [markdown]
# > #### **Part A**

# %% [markdown]
# #### **1. Create a flow chart for function 2**
#
# Create the flow chart for calculate_ maintenance _status.
#
# 1.1 Determine the flow of the function calculate_maintenance_status.
#
# 1.2 Fill in the Flowchart template in **Annex A**.

# %% [markdown]
# #### **2. Open the downloaded PA_1.ipynb file using JupyterLab Notebook.**
#
# Screenshots of the file can be found in Annex B.

# %% [markdown]
# #### **3. Write the Pseudocode for the Main Program**
#
# 3.1  Using the comment syntax, fill in the pseudocode for the main program.

# %%
#User sees the welcome message and title:
# ______ welcome message and title

#Declare variables, list
# ______ machine names and last maintenance dates

#Function 1
# ______ to display maintenance dates and get user inputs

#Function 2
# ______ to calculate days remaining and check overdue status

#See the out of the program
# ______ final maintenance status report
# ______ overdue maintenance warnings

# %% [markdown]
# #### **4. Declare the variables for the program**
#
# 4.1 Fill in the missing variable declaration.

# %%
from datetime import datetime 

# Constants
MAINTENANCE_CYCLE_DAYS = ____ # Integer constant for 90-day maintenance cycle

# Machine information
machine_names = ["______________","_______________"]  # List of strings - machine names
last_maintenance_dates = ["12/01/26","12/06/26"]  # List of strings in DD/MM/YY format, enter any dates

# User input variables
daily_check_cnc = "" # String variable to store CNC daily check response
daily_check_press = "" # String variable to store Press daily check response
current_date_str = ""  # String variable to store user input date

# Calculated variables  
current_date = None  # datetime object - will store converted current date
days_since_maintenance = []  # List to store calculated days for each machine
maintenance_status =  [] # List to store status strings for each machine

# %% [markdown]
# > #### **Part B**

# %% [markdown]
# #### **4. Write the code for function 1**
#
# 4.1 Fill in the missing syntax of the function method to display machine information and get user inputs.

# %%
def display_and_get_inputs(machine_names , last_maintenance_dates):  # Function definition with parameters
    """
    Function 1: Display machine information and get user inputs
    """
    print("=== Precision Manufacturing Solutions - Maintenance Tracker ===\n")  # Print header with \n for new line
    
    # Display last maintenance dates
    print("Last 90-day Maintenance Dates:")  # Print section title
    for _ in range(len(machine_names)):  # For loop - i from 0 to length of list
        print(f"- {machine_names[i]}: {last_maintenance_dates[i]}")  # f-string formatting to insert variables
    
    print("\nDaily Check Completion:")  # Print section title with \n for blank line
    
    # Get daily check inputs
    daily_check_1 = __(f"Was daily check completed for {machine_names[0]}? (yes/no): ")  
    daily_check_2 = __(f"Was daily check completed for {machine_names[1]}? (yes/no): ")  
    
    # Get current date
    current_date_str = __("Enter today's check date (DD/MM/YY): ")  
    
    return daily_check_1, daily_check_2, current_date_str  # return statement with multiple values (tuple)

# %% [markdown]
# #### **5. Write the code for function 2**
#
# 5.1 Fill in the missing syntax of the function method to calculate days remaining and check for overdue maintenance.

# %%
def calculate_maintenance_status(machine_names, last_maintenance_dates, current_date_str):  # Function definition with 3 parameters
    """
    Function 2: Calculate days remaining and check for overdue maintenance
    """
    # Convert current date string to datetime object
    current_date = datetime.strptime(current_date_str, "%d/%m/%y")  # strptime() method converts string to datetime using format
    
    print("\n=== Maintenance Status Report ===")  # Print section header
    
    for _ in range(len(__)):  # For loop through each machine using index
        # Convert last maintenance date to datetime object
        last_date = datetime.strptime(last_maintenance_dates[i], "%d/%m/%y")  # Convert string at index i to datetime
        
        # Calculate days since last maintenance
        days_since = (current_date - last_date).days  # Subtract datetime objects, .days gets integer days
        
        print(f"\n{machine_names[i]}:")  # Print machine name using f-string and list index
        print(f"- Days since last maintenance: {days_since} days")  # Print calculated days using f-string
        
        # Check if overdue (more than 90 days)
        _ days_since _ MAINTENANCE_CYCLE_DAYS:  # if statement comparing with constant
            overdue_days = days_since - MAINTENANCE_CYCLE_DAYS  # Calculate overdue amount
            print(f"- Status: OVERDUE by {overdue_days} day(s)")  # Print overdue status with f-string
            print("- ACTION REQUIRED: Please place maintenance tag immediately!")  # Print warning message
        __:  # else clause for when not overdue
            days_remaining = __  # Calculate remaining days
            print(f"- Days remaining until next maintenance: {days_remaining} days")  # Print remaining days
             # Print OK status

# %% [markdown]
# #### **6. Write the main program**
#
#
# 6.1. Fill in the missing syntax of the main program that coordinates the entire maintenance tracking system .

# %%
def main():  # Main function definition with no parameters
    """
    Main program that coordinates the entire maintenance tracking system
    """
    # Initialize data
    machine_names = ["CNC Milling Machine", "Hydraulic Press"]  # Local list variable
    last_maintenance_dates = ["14/08/25","21/11/25"]  # List of strings in DD/MM/YY format, enter any dates
    
    # Call function 1 to display info and get inputs
    daily_check_1, daily_check_2, current_date_str = display_and_get_inputs(machine_names, last_maintenance_dates) # Function call with tuple unpacking
    
    # Call function 2 to calculate and display maintenance status
    _________(machine_names, last_maintenance_dates, current_date_str)   # Function call with 3 arguments

# Call the main function
if __name__ == "__main__":  # Special Python idiom - only run if script executed directly
      # Call main function
# Out:
#   Cell In[4], line 18
#
#     ^
# _IncompleteInputError: incomplete input
